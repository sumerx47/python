# %% [markdown]
# # sequence practise exercise

# %%
number = [1,2,3,4,5]
number
# Out:
# [1, 2, 3, 4, 5]

# %%
colors=('red','blue','green','black','white')
colors
# Out:
# ('red', 'blue', 'green', 'black', 'white')

# %%
colors[-2:]
# Out:
# ('black', 'white')

# %%
a=[12,3,44,12,43,433]
a[::2]
# Out:
# [12, 44, 43]

# %%
b=range(0,5)
b
# Out:
# range(0, 5)

# %%
b=list(b)
b
# Out:
# [0, 1, 2, 3, 4]
