# %% [markdown]
# attendance = [
#     ("Ali","Present"),
#     ("Sara","Absent"),
#     ("John","Present"),
#     ("Ali","Present"),
#     ("Sara","Present")
# ]
# Find:
# Total attendance of each student
# Number of presents and absents
#
#
# Students = [
#     {
#         "name": "Ali",
#         "subjects": {
#             "Math": 90,
#             "Science": 85,
#             "English": 88
#         }
#     },
#     {
#         "name": "Sara",
#         "subjects": {
#             "Math": 95,
#             "Science": 92,
#             "English": 89
#         }
#     },
#     {
#         "name": "John",
#         "subjects": {
#             "Math": 78,
#             "Science": 81,
#             "English": 75
#         }
#     },
#     {
#         "name": "Fatima",
#         "subjects": {
#             "Math": 88,
#             "Science": 90,
#             "English": 94
#         }
#     },
#     {
#         "name": "Ahmed",
#         "subjects": {
#             "Math": 84,
#             "Science": 79,
#             "English": 91
#         }
#     }
# ]
#
#
#  Write a Python program to:
# Print every student's name and marks.
# Calculate the total marks of each student.
# Calculate the average marks of each student.
# Assign grades:
# Average ≥ 90 → Grade A
# Average ≥ 80 → Grade B
# Average ≥ 70 → Grade C
# Otherwise → Grade D
# Find the class topper.
# Find the subject-wise topper in:
# Math
# Science
# English
# Print students who scored more than 90 in any subject.
# Find the overall class average.
# Print students whose average is below the class average.
# Find which subject has the highest class average.

# %%
'''Count the occurrence of each word in a sentence.
output:
python : 2
is : 2
easy : 1
powerful : 1'''

sentence = "python is easy python is powerful"

# %%
words= sentence.lower().split()
words
# Out:
# ['python', 'is', 'easy', 'python', 'is', 'powerful']

# %%
freq = {}

# %%
for word in words:
    if word in words:
        freq = word + 1  
print(freq)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 3
#       1 for word in words:
#       2     if word in words:
# ----> 3         freq = word + 1
#       4 print(freq)
#
# TypeError: can only concatenate str (not "int") to str

# %%
'''Find:
Total attendance of each student
Number of presents and absents'''

attendance = [
    ("Ali","Present"),
    ("Sara","Absent"),
    ("John","Present"),
    ("Ali","Present"),
    ("Sara","Present")
]

# %%
s= set()

# %%
for students in attendance:
    s.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 2
#       1 for stu in attendance:
# ----> 2     s.attendance(stu)
#
# AttributeError: 'set' object has no attribute 'attendance'

# %%
Students = [
    {
        "name": "Ali",
        "subjects": {
            "Math": 90,
            "Science": 85,
            "English": 88
        }
    },
    {
        "name": "Sara",
        "subjects": {
            "Math": 95,
            "Science": 92,
            "English": 89
        }
    },
    {
        "name": "John",
        "subjects": {
            "Math": 78,
            "Science": 81,
            "English": 75
        }
    },
    {
        "name": "Fatima",
        "subjects": {
            "Math": 88,
            "Science": 90,
            "English": 94
        }
    },
    {
        "name": "Ahmed",
        "subjects": {
            "Math": 84,
            "Science": 79,
            "English": 91
        }
    }
]


'''Write a Python program to:
Print every student's name and marks.
Calculate the total marks of each student.
Calculate the average marks of each student.
Assign grades:
Average ≥ 90 → Grade A
Average ≥ 80 → Grade B
Average ≥ 70 → Grade C
Otherwise → Grade D
Find the class topper.
Find the subject-wise topper in:
Math
Science
English
Print students who scored more than 90 in any subject.
Find the overall class average.
Print students whose average is below the class average.
Find which subject has the highest class average.'''
# Out:
# "Write a Python program to:\nPrint every student's name and marks.\nCalculate the total marks of each student.\nCalculate the average marks of each student.\nAssign grades:\nAverage ≥ 90 → Grade A\nAverage ≥ 80 → Grade B\nAverage ≥ 70 → Grade C\nOtherwise → Grade D\nFind the class topper.\nFind the subject-wise topper in:\nMath\nScience\nEnglish\nPrint students who scored more than 90 in any subject.\nFind the overall class average.\nPrint students whose average is below the class average.\nFind which subject has the highest class average."

# %%
for student in Students:
    print(student)
# Out:
# {'name': 'Ali', 'subjects': {'Math': 90, 'Science': 85, 'English': 88}}
# {'name': 'Sara', 'subjects': {'Math': 95, 'Science': 92, 'English': 89}}
# {'name': 'John', 'subjects': {'Math': 78, 'Science': 81, 'English': 75}}
# {'name': 'Fatima', 'subjects': {'Math': 88, 'Science': 90, 'English': 94}}
# {'name': 'Ahmed', 'subjects': {'Math': 84, 'Science': 79, 'English': 91}}

# %%
for student in Students:
    totals = sum(student["subjects"].values())
    print(student["name"], ":", totals)
# Out:
# Ali : 263
# Sara : 276
# John : 234
# Fatima : 272
# Ahmed : 254

# %%
len(Students)
# Out:
# 5

# %%
for student in Students:
    totals = sum(student["subjects"].values())
    Average = totals / len(student["subjects"])
    student["avg"] = Average

# %%
Students
# Out:
# [{'name': 'Ali',
#   'subjects': {'Math': 90, 'Science': 85, 'English': 88},
#   'avg': 87.66666666666667},
#  {'name': 'Sara',
#   'subjects': {'Math': 95, 'Science': 92, 'English': 89},
#   'avg': 92.0},
#  {'name': 'John',
#   'subjects': {'Math': 78, 'Science': 81, 'English': 75},
#   'avg': 78.0},
#  {'name': 'Fatima',
#   'subjects': {'Math': 88, 'Science': 90, 'English': 94},
#   'avg': 90.66666666666667},
#  {'name': 'Ahmed',
#   'subjects': {'Math': 84, 'Science': 79, 'English': 91},
#   'avg': 84.66666666666667}]

# %%
for student in Students:
    totals = sum(student["subjects"].values())
    Average = totals / len(student["subjects"])
    student["avg"] = Average

    if Average >= 90 :
        print("→ Grade A")
    elif Average >= 80: 
        print("→ Grade B")
    elif Average >= 70: 
        print("→ Grade C")
    else:
        print("→ Grade D")
    student["Grade"] = Students
Students
# Out:
# → Grade B
# → Grade A
# → Grade C
# → Grade A
# → Grade B
# [{'name': 'Ali',
#   'subjects': {'Math': 90, 'Science': 85, 'English': 88},
#   'avg': 87.66666666666667,
#   'Grade': [...]},
#  {'name': 'Sara',
#   'subjects': {'Math': 95, 'Science': 92, 'English': 89},
#   'avg': 92.0,
#   'Grade': [...]},
#  {'name': 'John',
#   'subjects': {'Math': 78, 'Science': 81, 'English': 75},
#   'avg': 78.0,
#   'Grade': [...]},
#  {'name': 'Fatima',
#   'subjects': {'Math': 88, 'Science': 90, 'English': 94},
#   'avg': 90.66666666666667,
#   'Grade': [...]},
#  {'name': 'Ahmed',
#   'subjects': {'Math': 84, 'Science': 79, 'English': 91},
#   'avg': 84.66666666666667,
#   'Grade': [...]}]
