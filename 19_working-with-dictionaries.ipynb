# %% [markdown]
# # Working with Dictionaries

# %%
data={
    'open':100,
    'high':110,
    'low':95,
    'close':110,
    3.14:'pi'
}

# %%
'open' in data
# Out:
# True

# %%
3.14 in data
# Out:
# True

# %%
'open' not in data
# Out:
# False

# %%
"x" not in data
# Out:
# True

# %%
l=[1,2,3,4]

# %%
3 in l
# Out:
# True

# %%
5 not in l
# Out:
# True

# %%
3 not in l
# Out:
# False
