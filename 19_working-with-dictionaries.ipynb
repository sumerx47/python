# %% [markdown]
# # Working with Dictionaries

# %%
data={
    'open':100,
    'high':110,
    'low':95,
    'close':110,
    3.14:'pi'
}

# %%
'open' in data
# Out:
# True

# %%
3.14 in data
# Out:
# True

# %%
'open' not in data
# Out:
# False

# %%
"x" not in data
# Out:
# True

# %%
l=[1,2,3,4]

# %%
3 in l
# Out:
# True

# %%
5 not in l
# Out:
# True

# %%
3 not in l
# Out:
# False

# %%
data
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 3.14: 'pi'}

# %%
data.clear()

# %%
data
# Out:
# {}

# %%
len(data)
# Out:
# 0

# %%
data={
    'open':100,
    'high':110,
    'low':95,
    'close':110,
    3.14:'pi'
}

# %%
len(data)
# Out:
# 5

# %%
data_copy=data.copy()
data
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 3.14: 'pi'}

# %%
data_copy
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 3.14: 'pi'}

# %%
data is data_copy
# Out:
# False

# %%
data_copy is data
# Out:
# False

# %%
data_copy['x']=100
data_copy
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 3.14: 'pi', 'x': 100}

# %%
data
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 3.14: 'pi'}

# %%
data['new']=111
data
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 3.14: 'pi', 'new': 111}

# %%
data_copy
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 3.14: 'pi', 'x': 100}

# %%
from copy import deepcopy

# %%
new_copy=deepcopy(data)
new_copy
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 3.14: 'pi'}

# %%
new_copy is data
# Out:
# False

# %%
d={
    'a':[1,2,3],
    'b':{
        'x':0,
        'y':0
    }
    
}

# %%
d
# Out:
# {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}}

# %%
n_copy =d.copy()

# %%
n_copy is d
# Out:
# False

# %%
d['b']=100
d
# Out:
# {'a': [1, 2, 3], 'b': 100}

# %%
n_copy
# Out:
# {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}}

# %%
d, n_copy
# Out:
# ({'a': [1, 2, 3], 'b': 100}, {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}})

# %%
d['a'].append(4)

# %%
d
# Out:
# {'a': [1, 2, 3, 4], 'b': 100}

# %%
n_copy
# Out:
# {'a': [1, 2, 3, 4], 'b': {'x': 0, 'y': 0}}

# %%
n_copy = deepcopy(d)

# %%
d
# Out:
# {'a': [1, 2, 3, 4], 'b': 100}

# %%
n_copy['a'].append(5)

# %%
n_copy
# Out:
# {'a': [1, 2, 3, 4, 5], 'b': 100}

# %%
d
# Out:
# {'a': [1, 2, 3, 4], 'b': 100}

# %%
d['a'].append(6)

# %%
d
# Out:
# {'a': [1, 2, 3, 4, 6], 'b': 100}

# %%
n_copy
# Out:
# {'a': [1, 2, 3, 4, 5], 'b': 100}

# %%
da={
    'open':100,
    'high':110,
    'low':95,
    'close':110
}

# %%
nw_copy = deepcopy(da)

# %%
da
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110}

# %%
nw_copy
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110}

# %%
nw_copy['ji']=15
nw_copy
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 'ji': 15}

# %%
da
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110}

# %%
da['zaz']=147
da
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 'zaz': 147}

# %%
nw_copy
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 'ji': 15}

# %%
o={
    'a':[1,2,3],
    'b':{
        'x':0,
        'y':0
    }
    
}

# %%
o
# Out:
# {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}}

# %%
ncopy =o.copy()

# %%
o
# Out:
# {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}}

# %%
ncopy
# Out:
# {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}}

# %%
ncopy["sa"]=74
ncopy
# Out:
# {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}, 'sa': 74}

# %%
o
# Out:
# {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}}

# %%
o['case']=98
o
# Out:
# {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}, 'case': 98}

# %%
ncopy
# Out:
# {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}, 'sa': 74}

# %%
ncopy['a'].append(1)
ncopy
# Out:
# {'a': [1, 2, 3, 1], 'b': {'x': 0, 'y': 0}, 'sa': 74}

# %%
o
# Out:
# {'a': [1, 2, 3, 1], 'b': {'x': 0, 'y': 0}, 'case': 98}

# %%
o['a'].append(6)
o
# Out:
# {'a': [1, 2, 3, 1, 6, 6], 'b': {'x': 0, 'y': 0}, 'case': 98}

# %%
ncopy
# Out:
# {'a': [1, 2, 3, 1, 6, 6], 'b': {'x': 0, 'y': 0}, 'sa': 74}

# %%
p={
    'a':[1,2,3],
    'b':{
        'x':0,
        'y':0
    }
    
}

# %%
my=p.copy()
my
# Out:
# {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}}

# %%
my['a'].append(36)
my
# Out:
# {'a': [1, 2, 3, 36], 'b': {'x': 0, 'y': 0}}

# %%
p
# Out:
# {'a': [1, 2, 3, 36], 'b': {'x': 0, 'y': 0}}

# %%
p['a'].append(555)
p
# Out:
# {'a': [1, 2, 3, 36, 555], 'b': {'x': 0, 'y': 0}}

# %%
my
# Out:
# {'a': [1, 2, 3, 36, 555], 'b': {'x': 0, 'y': 0}}

# %%
p['a'].append(2)
p

# %%
import copy

# %%
original=[[1,2],[3,4]]
original
# Out:
# [[1, 2], [3, 4]]

# %%
shallow=copy.copy(original)

# %%
shallow
# Out:
# [[1, 2], [3, 4]]

# %%
shallow[0][0]=110
shallow
# Out:
# [[110, 2], [3, 4]]

# %%
original
# Out:
# [[110, 2], [3, 4]]

# %%
original[0][1]=999
original
# Out:
# [[110, 999], [3, 4]]

# %%
shallow
# Out:
# [[110, 999], [3, 4]]

# %%
org=[[1,2],[3,4]]
org
# Out:
# [[1, 2], [3, 4]]

# %%
deep=copy.deepcopy(org)

# %%
deep
# Out:
# [[1, 2], [3, 4]]

# %%
deep[0].append(5)
deep
# Out:
# [[1, 2, 5], [3, 4]]

# %%
org
# Out:
# [[1, 2], [3, 4]]

# %%
org[0].append(88)
org
# Out:
# [[1, 2, 88], [3, 4]]

# %%
deep
# Out:
# [[1, 2, 5], [3, 4]]

# %%
deep[0][0]=100
deep
# Out:
# [[100, 2, 5], [3, 4]]

# %%
org
# Out:
# [[1, 2, 88], [3, 4]]

# %%
org[0][1]=2558
org
# Out:
# [[1, 2558, 88], [3, 4]]

# %%
deep
# Out:
# [[100, 2, 5], [3, 4]]
