# %% [markdown]
# # For Loops Coding

# %%
suits = ['hearts', 'clubs', 'diamonds', 'spades']

# %%
for s in suits:
 print(s)
# Out:
# hearts
# clubs
# diamonds
# spades

# %%
for s in suits:
 word = s[0].upper()
 print(f"{word} = {s}")
# Out:
# H = hearts
# C = clubs
# D = diamonds
# S = spades

# %%
for s in suits:
 print(f"{s[0].upper()} = {s}")
# Out:
# H = hearts
# C = clubs
# D = diamonds
# S = spades
