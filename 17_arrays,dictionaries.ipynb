# %% [markdown]
# # Arrays & Dictionaries

# %%
d={
    "a":1,
    "b":2,
    "c":3
}

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
person ={
    "name": "eric",
    "age":21,
    "married": True
}

# %%
person["age"]
# Out:
# 21

# %%
person["age"]=26

# %%
person
# Out:
# {'name': 'eric', 'age': 26, 'married': True}

# %%
person["born"]="portugal"
person
# Out:
# {'name': 'eric', 'age': 26, 'married': True, 'born': 'portugal'}

# %%
d={
    3.14:"pi",
    2:"even",
    "prime":7
}

# %%
d
# Out:
# {3.14: 'pi', 2: 'even', 'prime': 7}

# %%
d[3.14]
# Out:
# 'pi'

# %%
d[2]
# Out:
# 'even'

# %%
l=[1,2,3]

# %%
d={l:100}
d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 d={l:100}
#       2 d
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
hash(100)
# Out:
# 100

# %%
hash(3.14)
# Out:
# 322818021289917443

# %%
t=(1,2,3,4)

# %%
hash(t)
# Out:
# 590899387183067792

# %%
t=([1,2],3,4)

# %%
hash(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 hash(t)
#
# TypeError: unhashable type: 'list'

# %%
d={
    (0,0):"origin",
    (1,0):"unit-x",
    (0,1):"unit-y"
}

# %%
d[(0,0)]
# Out:
# 'origin'

# %%
d={'a':1,'b':2,'c':3}

# %%
id(d)
# Out:
# 2421963141760
