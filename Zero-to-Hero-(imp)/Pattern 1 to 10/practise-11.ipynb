# %% [markdown]
# # Practise coding Basics to Advanced+ Level
# ### patterns 1-10
# ### chapters 1-13

# %% [markdown]
# Question
#
#    ↓
#
# What data do I have?
#
#    ↓
#
# Which pattern?
#
#    ↓
#
# Loop?
#
#    ↓
#
# Condition?
#
#    ↓
#
# Result container?
#
#    ↓
#
# return result

# %% [markdown]
# 🟢 LEVEL 1 — BASIC
#
# Q1. Function to find highest number
