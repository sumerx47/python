# %% [markdown]
# # 6. Sorting
# ## Intermediate to Advanced

# %% [markdown]
# 🟡 Level 2 (Intermediate)
#
# Question 1 – Employee Salary
#
# Tasks
#
# 1. Sort by salary (ascending)
#
#
# 2. Sort by salary (descending)
#
#
# 3. Sort by employee name (A–Z)
#
#
# 4. Sort by employee name (Z–A)

# %%
employees = [
    {"name":"Ali","salary":45000},
    {"name":"Sara","salary":70000},
    {"name":"Ahmed","salary":60000},
    {"name":"John","salary":35000},
    {"name":"Fatima","salary":80000}
]

# %%
print(sorted(employees, key = lambda x:x["salary"]))
print(sorted(employees, key = lambda x:x["salary"], reverse = True))
print("*"*15)
print(sorted(employees, key = lambda x:x["name"]))
print(sorted(employees, key = lambda x:x["name"], reverse = True))
# Out:
# [{'name': 'John', 'salary': 35000}, {'name': 'Ali', 'salary': 45000}, {'name': 'Ahmed', 'salary': 60000}, {'name': 'Sara', 'salary': 70000}, {'name': 'Fatima', 'salary': 80000}]
# [{'name': 'Fatima', 'salary': 80000}, {'name': 'Sara', 'salary': 70000}, {'name': 'Ahmed', 'salary': 60000}, {'name': 'Ali', 'salary': 45000}, {'name': 'John', 'salary': 35000}]
# ***************
# [{'name': 'Ahmed', 'salary': 60000}, {'name': 'Ali', 'salary': 45000}, {'name': 'Fatima', 'salary': 80000}, {'name': 'John', 'salary': 35000}, {'name': 'Sara', 'salary': 70000}]
# [{'name': 'Sara', 'salary': 70000}, {'name': 'John', 'salary': 35000}, {'name': 'Fatima', 'salary': 80000}, {'name': 'Ali', 'salary': 45000}, {'name': 'Ahmed', 'salary': 60000}]

# %% [markdown]
# Question 2 – Students
#
#
#
# Tasks
#
# 1. Sort by marks (ascending)
#
#
# 2. Sort by marks (descending)
#
#
# 3. Sort by name (A–Z)
#
#
# 4. Sort by name (Z–A)

# %%
students = [
    {"name":"Ali","marks":90},
    {"name":"Sara","marks":65},
    {"name":"Ahmed","marks":82},
    {"name":"John","marks":45},
    {"name":"Fatima","marks":96}
]

# %%
marks_ascending = sorted(students, key = lambda student:student["marks"])
marks_descending =sorted(students, key = lambda student:student["marks"], reverse= True)

name_ascending =sorted(students, key = lambda student:student["name"])
name_descending =sorted(students, key = lambda student:student["name"], reverse =True)

print(marks_ascending)
print(marks_descending)
print(name_ascending)
print(name_descending)
# Out:
# [{'name': 'John', 'marks': 45}, {'name': 'Sara', 'marks': 65}, {'name': 'Ahmed', 'marks': 82}, {'name': 'Ali', 'marks': 90}, {'name': 'Fatima', 'marks': 96}]
# [{'name': 'Fatima', 'marks': 96}, {'name': 'Ali', 'marks': 90}, {'name': 'Ahmed', 'marks': 82}, {'name': 'Sara', 'marks': 65}, {'name': 'John', 'marks': 45}]
# [{'name': 'Ahmed', 'marks': 82}, {'name': 'Ali', 'marks': 90}, {'name': 'Fatima', 'marks': 96}, {'name': 'John', 'marks': 45}, {'name': 'Sara', 'marks': 65}]
# [{'name': 'Sara', 'marks': 65}, {'name': 'John', 'marks': 45}, {'name': 'Fatima', 'marks': 96}, {'name': 'Ali', 'marks': 90}, {'name': 'Ahmed', 'marks': 82}]

# %% [markdown]
# 🔴 Level 4 (2-Year Experience)
#
# Question 9 – Employees
#
#
#
# Tasks
#
# 1. Sort by salary
#
#
# 2. Sort by department
#
#
# 3. Sort by employee name
#
#
# 4. Sort by salary (highest first)

# %%
employees = [
    {"name":"Ali","dept":"IT","salary":45000},
    {"name":"Sara","dept":"HR","salary":70000},
    {"name":"Ahmed","dept":"IT","salary":60000},
    {"name":"John","dept":"Finance","salary":35000},
    {"name":"Fatima","dept":"HR","salary":80000}
]

# %%
print("salary_descending: ", sorted(employees, key =lambda x:x['salary'], reverse = True))
print("salary_ascending: ", sorted(employees, key = lambda x:x["salary"]))
print("dept_ascending: ", sorted(employees, key = lambda x:x["dept"]))
print("name_ascending: ", sorted(employees, key = lambda x:x["name"]))
# Out:
# salary_descending:  [{'name': 'Fatima', 'dept': 'HR', 'salary': 80000}, {'name': 'Sara', 'dept': 'HR', 'salary': 70000}, {'name': 'Ahmed', 'dept': 'IT', 'salary': 60000}, {'name': 'Ali', 'dept': 'IT', 'salary': 45000}, {'name': 'John', 'dept': 'Finance', 'salary': 35000}]
# salary_ascending:  [{'name': 'John', 'dept': 'Finance', 'salary': 35000}, {'name': 'Ali', 'dept': 'IT', 'salary': 45000}, {'name': 'Ahmed', 'dept': 'IT', 'salary': 60000}, {'name': 'Sara', 'dept': 'HR', 'salary': 70000}, {'name': 'Fatima', 'dept': 'HR', 'salary': 80000}]
# dept_ascending:  [{'name': 'John', 'dept': 'Finance', 'salary': 35000}, {'name': 'Sara', 'dept': 'HR', 'salary': 70000}, {'name': 'Fatima', 'dept': 'HR', 'salary': 80000}, {'name': 'Ali', 'dept': 'IT', 'salary': 45000}, {'name': 'Ahmed', 'dept': 'IT', 'salary': 60000}]
# ...

# %% [markdown]
# Question 13 – Multi-Key Sorting
#
# Tasks
#
# 1. Sort by salary, then name.
#
#
# 2. Sort by department, then salary.

# %%
employees = [
    {"name":"Ali","dept":"IT","salary":50000},
    {"name":"Sara","dept":"HR","salary":50000},
    {"name":"Ahmed","dept":"IT","salary":70000},
    {"name":"John","dept":"HR","salary":70000},
    {"name":"Fatima","dept":"IT","salary":50000}
]

# %%
print(sorted(employees , key = lambda x: (x["salary"],x["name"])))
print(sorted(employees, key= lambda x: (x["dept"],x["salary"])))
# Out:
# [{'name': 'John', 'dept': 'Finance', 'salary': 35000}, {'name': 'Ali', 'dept': 'IT', 'salary': 45000}, {'name': 'Ahmed', 'dept': 'IT', 'salary': 60000}, {'name': 'Sara', 'dept': 'HR', 'salary': 70000}, {'name': 'Fatima', 'dept': 'HR', 'salary': 80000}]
# [{'name': 'John', 'dept': 'Finance', 'salary': 35000}, {'name': 'Sara', 'dept': 'HR', 'salary': 70000}, {'name': 'Fatima', 'dept': 'HR', 'salary': 80000}, {'name': 'Ali', 'dept': 'IT', 'salary': 45000}, {'name': 'Ahmed', 'dept': 'IT', 'salary': 60000}]

# %%
emp = employees.copy()

emp.sort(key = lambda x: (x["salary"],x["name"]))
print(emp)
emp.sort(key= lambda x: (x["dept"],x["salary"]))
print(emp)
# Out:
# [{'name': 'Ali', 'dept': 'IT', 'salary': 50000}, {'name': 'Fatima', 'dept': 'IT', 'salary': 50000}, {'name': 'Sara', 'dept': 'HR', 'salary': 50000}, {'name': 'Ahmed', 'dept': 'IT', 'salary': 70000}, {'name': 'John', 'dept': 'HR', 'salary': 70000}]
# [{'name': 'Sara', 'dept': 'HR', 'salary': 50000}, {'name': 'John', 'dept': 'HR', 'salary': 70000}, {'name': 'Ali', 'dept': 'IT', 'salary': 50000}, {'name': 'Fatima', 'dept': 'IT', 'salary': 50000}, {'name': 'Ahmed', 'dept': 'IT', 'salary': 70000}]
