# %% [markdown]
# # unpacking sequence

# %%
price=5.0,5.12

# %%
price[0],price[1]
# Out:
# (5.0, 5.12)

# %%
a=price[0]
b=price[1]

# %%
a,b
# Out:
# (5.0, 5.12)

# %%
a,b=price
a,b
# Out:
# (5.0, 5.12)

# %%
a,b,c=10,20,30

# %%
a,b,c
# Out:
# (10, 20, 30)

# %%
x,y,z=10,'hello',2.9

# %%
x
# Out:
# 10

# %%
y
# Out:
# 'hello'

# %%
z
# Out:
# 2.9

# %%
type(x),type(y),type(z)
# Out:
# (int, str, float)

# %%
a= 10 * 2**3 + 5
a
# Out:
# 85

# %%
s='python'
a,b,c=(1+1, s[::-1], 4.4)
a,b,c
# Out:
# (2, 'nohtyp', 4.4)

# %%
d=(a,b,c)
d
# Out:
# (2, 'nohtyp', 4.4)

# %%
d=list(d)
d
# Out:
# [2, 'nohtyp', 4.4]

# %%
d.append(10)
d
# Out:
# [2, 'nohtyp', 4.4, 10]

# %%
d.insert(2,'cython')
d
# Out:
# [2, 'nohtyp', 'cython', 4.4, 10]

# %%
d=tuple(d)
d
# Out:
# (2, 'nohtyp', 'cython', 4.4, 10)

# %%
type(d)
# Out:
# tuple

# %%
d=str(d)
d
# Out:
# "(2, 'nohtyp', 'cython', 4.4, 10)"

# %%
type(d)
# Out:
# str
