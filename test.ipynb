# %% [markdown]
# # lists

# %%
name = "i am sumair"
name
# Out:
# 'i am sumair'

# %%
name.strip()
# Out:
# 'i am sumair'

# %%
l=list(name)
l
# Out:
# ['i', ' ', 'a', 'm', ' ', 's', 'u', 'm', 'a', 'i', 'r']

# %%
g = []
for i in l:
    if i!= " ":
        g.append(i)

print(g)
# Out:
# ['i', 'a', 'm', 's', 'u', 'm', 'a', 'i', 'r']

# %%
a = "aei;oui:rtv<"

# %%
list_strings = []
for i in a:
    if i in ";:<":
        continue
    else:
        list_strings.append(i)
print(list_strings)
# Out:
# ['a', 'e', 'i', 'o', 'u', 'i', 'r', 't', 'v']
