# %% [markdown]
# # unicode - strings

# %%
ord('A')
# Out:
# 65

# %%
ord('a')
# Out:
# 97

# %%
hex(ord('A'))
# Out:
# '0x41'

# %%
hex(ord('a'))
# Out:
# '0x61'

# %%
int('0x61',16)
# Out:
# 97

# %%
var="\N{Latin Capital Letter A}lways look in the bright side of life"
var
# Out:
# 'Always look in the bright side of life'

# %%
var="\U00000041lways look in the bright side of life"
var
# Out:
# 'Always look in the bright side of life'

# %%
var="\u0041lways look in the bright side of life"
var
# Out:
# 'Always look in the bright side of life'
