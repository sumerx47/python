# %% [markdown]
# ## PRACTISE

# %%
print("hello")
# Out:
# hello

# %%
for i in range(8):
 print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
from datetime import datetime
current = datetime.utcnow()
current
# Out:
# C:\Users\sumair\AppData\Local\Temp\ipykernel_13964\757006949.py:2: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   current = datetime.utcnow()
# datetime.datetime(2026, 7, 24, 19, 25, 41, 602935)

# %%
1
# Out:
# 1

# %% [markdown]
# ### 3. python basics

# %%
#format(0.1, ',25f')
#format()

# %%
0.125+0.125+0.125 == 0.375
# Out:
# True

# %%
(10).__add__(25)
# Out:
# 35

# %%
(0.125).as_integer_ratio()
# Out:
# (1, 8)

# %%
(0.1).as_integer_ratio()
# Out:
# (3602879701896397, 36028797018963968)

# %%
10 ==10
# Out:
# True

# %%
2**8
# Out:
# 256

# %%
(-4) ** 0.5
# Out:
# (1.2246467991473532e-16+2j)

# %%
165-(163//60*60)
# Out:
# 45

# %%
elapsed_minutes=485
hours=elapsed_minutes//60
remaining_minutes=elapsed_minutes%60
print(hours,remaining_minutes)
# Out:
# 8 5

# %%
total=0
for i in range(1,10):
    total+=i
    if i%2==0:
     print(f'total={total}...')
print(f'final total={total}')
# Out:
# total=3...
# total=10...
# total=21...
# total=36...
# final total=45

# %%
a=10.0
b=10
a==b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
id(a), id(b)
# Out:
# (2433592815856, 140709069112728)

# %%
a = 256
b = 256
a is b
# Out:
# True

# %%
not True
# Out:
# False

# %%
balance =1000
withdrawl =500
withdrawl_limit=500

# %%
(withdrawl<=withdrawl_limit and [withdrawl<=balance])
# Out:
# [True]

# %%
A=100
Z=200
print("sum:",A+Z)
# Out:
# sum: 300

# %%
A=10
Z=20
Q=30
print("avg:",int((A+Z+Q)/3))
# Out:
# avg: 20

# %%
A=109
Z=209
A,Z=Z,A
print('A:',A ,'Z:',Z)
# Out:
# A: 209 Z: 109

# %%
if 1<2:
   print("it is true 1 is less than 2")
else:
   print("it is false") 
print("finished")
# Out:
# it is true 1 is less than 2
# finished

# %%
account_enabled = True
withdrawl=1000
withdraw_limit=300

if account_enabled and withdrawl<=withdraw_limit:
    print("authorised")
elif account_enabled and withdrawl>=withdraw_limit:
    print("withdrawl limit exceeded")
else:
    print("unauthorised USER")
# Out:
# withdrawl limit exceeded

# %%
grade=70
if grade> 100:
    print("enter correct marks")
elif grade>= 90:
    print("A")
elif grade>= 80:
    print("B")
elif grade>= 70:
    print("C")
elif grade< 0:
    print("negative marks entered")
else:
    print("F")
# Out:
# C

# %%
marks=-1
if marks> 100:
    grade=("enter correct marks")
elif marks>= 90:
    grade=("A")
elif marks>= 80:
    grade=("B")
elif marks>= 70:
    grade=("C")
elif marks< 0:
    grade=("negative marks entered")
else:
    grade=("F")
print("the grade is:", grade)
# Out:
# the grade is: negative marks entered

# %%
a=10
b=100
if a>=b:
    distance = a-b
else:
    distance = b-a 
distance
# Out:
# 90

# %%
a=1001
b=100
distance = a-b if a>=b else b-a 
distance
# Out:
# 901

# %%
x=12

if x>0:
   if x%2 == 0:
    print('postive even')
   else:
    print('postive odd')
else:
 print('negative')
# Out:
# postive even

# %%
a=1000
b=20
c=150
if a>=b and a>=c:
    print("largest number is:", a)
elif b>=a and b>=c:
    print("largest number is:", b)
else:
    print("largest number is:", c)
# Out:
# largest number is: 1000

# %%
year= 2027
if (year%4 ==0 and year%100 != 0) or (year%400==0):
  print("leap year")
else:
  print("NOT a leap year")
# Out:
# NOT a leap year

# %%
l=[12,34,4435,55,4,2,222]

# %%
len(l)
# Out:
# 7

# %%
l[-1], l[0]
# Out:
# (222, 12)

# %%
l=[]
type(l)
# Out:
# list

# %%
b=list()
type(b)
# Out:
# list

# %%
t=(1,2,3)
type(t), t
# Out:
# (tuple, (1, 2, 3))

# %%
l=list(t)
l
# Out:
# [1, 2, 3]

# %%
l[0]
# Out:
# 1

# %%
l[1]=100

# %%
l
# Out:
# [1, 100, 3]

# %%
l.append(999)

# %%
l[-2]=85

# %%
t=tuple(l)
t
# Out:
# (1, 100, 85, 999)

# %%
type(t)
# Out:
# tuple

# %%
t=()
t, type(t), len(t)
# Out:
# ((), tuple, 0)

# %%
t=(1,44,55,32,77)

# %%
type(t)
t
# Out:
# (1, 44, 55, 32, 77)

# %%
m=list[t]
m
# Out:
# list[1, 44, 55, 32, 77]

# %%
tup=10,33,2221,44

# %%
tup
# Out:
# (10, 33, 2221, 44)

# %%
lis=list(tup)
lis
# Out:
# [10, 33, 2221, 44]

# %%
lis[0]=22
lis
# Out:
# [22, 33, 2221, 44]

# %%
type(lis)
# Out:
# list

# %%
tu=tuple(lis)
tu, type(tu)
# Out:
# ((22, 33, 2221, 44), tuple)

# %%
t=[1,2],33,77
t
# Out:
# ([1, 2], 33, 77)

# %%
l=list(t)
l,type(l)
# Out:
# ([[1, 2], 33, 77], list)

# %%
l[0][1]=100
l
# Out:
# [[1, 100], 33, 77]

# %%
t=tuple(l)
t, type(t)
# Out:
# (([1, 100], 33, 77), tuple)

# %%
s="i am sumair"
type(s)
# Out:
# str

# %%
len(s)
# Out:
# 11

# %%
t=tuple(s)
t
# Out:
# ('i', ' ', 'a', 'm', ' ', 's', 'u', 'm', 'a', 'i', 'r')

# %%
l=list(t)
l
# Out:
# ['i', ' ', 'a', 'm', ' ', 's', 'u', 'm', 'a', 'i', 'r']

# %%
l[1]=8
l
# Out:
# ['i', 8, 'a', 'm', ' ', 's', 'u', 'm', 'a', 'i', 'r']

# %%
t=tuple(l)
t
# Out:
# ('i', 8, 'a', 'm', ' ', 's', 'u', 'm', 'a', 'i', 'r')

# %%
s = "".join(map(str,t))
print(s)
# Out:
# i8am sumair

# %%
z="i am sumair"
z
# Out:
# 'i am sumair'

# %%
m=[[0,0,0]]*3
m
# Out:
# [[0, 0, 0], [0, 0, 0], [0, 0, 0]]

# %%
m[0][0]=2
m
# Out:
# [[2, 0, 0], [2, 0, 0], [2, 0, 0]]

# %% [markdown]
# ## Slicing
