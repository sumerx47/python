# %% [markdown]
# # Test

# %%
 Write a Python program to:
1. Find the student with the highest marks.
2. Count how many students scored each unique mark.
3. Create a new list containing the names of students who scored 80 or above.
4. Sort the original list in descending order of marks.
5. Print the results in a readable format.

# %%
students = [
    {"name": "Alice", "marks": 85},
    {"name": "Bob", "marks": 72},
    {"name": "Charlie", "marks": 90},
    {"name": "David", "marks": 72},
    {"name": "Eva", "marks": 85},
    {"name": "Frank", "marks": 95}
]

# %%
highest = 0

# %%
for i in students:
    for k,v in i.items(): 
        if i["marks"] > highest:
            highest = i["marks"]

# %%
print(highest)
# Out:
# 95

# %% [markdown]
# ### 1. Find the student with the highest marks.

# %%
highest =0

# %%
for student in students:
  for k,v in student.items():
    if student["marks"] > highest:
        highest = student["marks"]
       
print(highest)
# Out:
# 95

# %% [markdown]
# ### 2. Count how many students scored each unique mark.

# %%
uniq = 0
freq={}

# %%
for student in students:
  for k,v in student.items():
    if student["marks"]  :
        uniq = student["marks"]
       
print(uniq)
# Out:
# 95

# %% [markdown]
# ### 3. Create a new list containing the names of students who scored 80 or above.

# %%
students = [
    {"name": "Alice", "marks": 85},
    {"name": "Bob", "marks": 72},
    {"name": "Charlie", "marks": 90},
    {"name": "David", "marks": 72},
    {"name": "Eva", "marks": 85},
    {"name": "Frank", "marks": 95}
]

# %%
highest = 80
l=[]

# %%
for student in students:
    if student["marks"] > highest:
      l.append(student["name"])

print(f"Names of students who scored 80 or above: {l}")
# Out:
# Names of students who scored 80 or above: ['Alice', 'Charlie', 'Eva', 'Frank']

# %%
students = [
    {"name": "Alice", "marks": 85},
    {"name": "Bob", "marks": 72},
    {"name": "Charlie", "marks": 90},
    {"name": "David", "marks": 72},
    {"name": "Eva", "marks": 85},
    {"name": "Frank", "marks": 95}
]

# %% [markdown]
# ### 4. Sort the original list in descending order of marks.

# %%
for student in students:
    if student["marks"] > highest:
      l.append(student["name"])

print(l)

# %%
fruits=["apple","banana","mango"]
for i,v in enumerate(fruits):
    print(i,v)
# Out:
# 0 apple
# 1 banana
# 2 mango

# %%
fruits={"apple":10,"banana":16,"mango":82}
for i,v in fruits.items():
    print(i,v)
# Out:
# apple 10
# banana 16
# mango 82

# %%
fruits={"apple":10,"banana":16,"mango":82}
for i,v in enumerate(fruits):
    print(i,v)
# Out:
# 0 apple
# 1 banana
# 2 mango

# %%
fruits={"apple":10,"banana":16,"mango":82}
for i,v in enumerate(fruits.items()):
    print(i,v)
# Out:
# 0 ('apple', 10)
# 1 ('banana', 16)
# 2 ('mango', 82)

# %%
names=["apple","banana","mango"]

# %%
prices=[85,90,95]

# %%
for n,p in zip(names, prices):
 print(n,p)
# Out:
# apple 85
# banana 90
# mango 95

# %%
fruits={"apple":10,"banana":16,"mango":82}
for i,v in sorted(fruits.items()):
    print(i,v)
# Out:
# apple 10
# banana 16
# mango 82

# %%
d={"apple":10,"banana":16,"mango":82}

# %%
d['mango']
# Out:
# 82

# %%
d.get('mango')
# Out:
# 82

# %%
'mango' in d
# Out:
# True

# %%
'mango' not in d
# Out:
# False

# %%
d={"apple":10,"banana":16,"mango":82}
fruits={"apple":100,"banana":163,"mango":182}

# %%
d.update(fruits)
d
# Out:
# {'apple': 100, 'banana': 163, 'mango': 182}

# %%
d={"apple":10,"banana":16,"mango":82}

# %%
for k in d:
    print(k,":",d[k])
# Out:
# apple : 10
# banana : 16
# mango : 82

# %%
for k,v in d.items():
   print(f"{k}: {v}")
# Out:
# apple: 10
# banana: 16
# mango: 82

# %%
d={"apple":10,"banana":116,"mango":82}

# %%
for v in sorted(d.values()):
    print(v)
# Out:
# 10
# 82
# 116

# %%
d1={"tomato":10,"banana":16,"tamarind":82}
fruitss={"apple":100,"banana":163,"mango":182}

# %%
h1= d1 | fruitss
d1 |= fruitss
print(h1)
# Out:
# {'tomato': 10, 'banana': 163, 'tamarind': 82, 'apple': 100, 'mango': 182}

# %%
h1
# Out:
# {'tomato': 10, 'banana': 163, 'tamarind': 82, 'apple': 100, 'mango': 182}
