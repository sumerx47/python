# %% [markdown]
# # String Methods

# %%
message="This is a programming language called as PYTHON."

# %%
message.upper()
# Out:
# 'THIS IS A PROGRAMMING LANGUAGE CALLED AS PYTHON.'

# %%
message.lower()
# Out:
# 'this is a programming language called as python.'

# %%
'abc'=='ABC'
# Out:
# False

# %%
'abc'=='abc'
# Out:
# True

# %%
'AbC'.lower()=='abC'.lower()
# Out:
# True

# %%
l='\u03b1'
u='\u0391'

# %%
l,u
# Out:
# ('α', 'Α')

# %%
l.casefold()==u.casefold()
# Out:
# True

# %%
street='stra\N{LATIN SMALL LETTER SHARP S}e'

# %%
street
# Out:
# 'straße'

# %%
street.upper()
# Out:
# 'STRASSE'

# %%
len(street), len(street.upper())
# Out:
# (6, 7)

# %%
name ='peter'

# %%
name.rstrip('')
# Out:
# 'peter'

# %%
name = '\tpeter \t \tjohn \t'

# %%
name
# Out:
# '\tpeter \t \tjohn \t'

# %%
print(name)
# Out:
# 	peter 	 	john

# %%
name.strip()
# Out:
# 'peter \t \tjohn'

# %%
name.strip('\t')
# Out:
# 'peter \t \tjohn '

# %%
name
# Out:
# '\tpeter \t \tjohn \t'

# %%
s='ababpythonabab'

# %%
s.strip('ab')
# Out:
# 'python'

# %%
s='ababcababpythonabab'

# %%
s.strip('ab')
# Out:
# 'cababpython'

# %%
s='ababbaababpythonabab'

# %%
s.strip('ab')
# Out:
# 'python'

# %%
"pythom"+" "+"HELLO"+"!"
# Out:
# 'pythom HELLO!'

# %%
"HELLO"+'!'+" "+'python'
# Out:
# 'HELLO! python'

# %%
data='hello!, james,peter'

# %%
split_data=data.split(',')

# %%
split_data
# Out:
# ['hello!', ' james', 'peter']

# %%
greeting,last_name, first_name= data.split(',')

# %%
greeting
# Out:
# 'hello!'

# %%
last_name
# Out:
# ' james'

# %%
first_name
# Out:
# 'peter'

# %%
data=['item 1','item 2','item 3']

# %%
', '.join(data)
# Out:
# 'item 1, item 2, item 3'

# %%
','.join('ABCD')
# Out:
# 'A,B,C,D'

# %%
1 in [1,2,3]
# Out:
# True

# %%
'abc' in ('abc', 'def')
# Out:
# True

# %%
"hello! python".startswith('hello')
# Out:
# True

# %%
"hello! python".endswith('hello')
# Out:
# False

# %%
"hello! python".endswith('on')
# Out:
# True

# %%
"hello! python".endswith('n')
# Out:
# True

# %%
"hello! python".endswith('python')
# Out:
# True

# %%
message='to every reaction there is an equal and opposite reaction'

# %%
message.index('reaction')
# Out:
# 9

# %%
message.index('newton')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 message.index('newton')
#
# ValueError: substring not found

# %%
message.find('newton')
# Out:
# -1

# %%
[1,2,3,4].index(2)
# Out:
# 1

# %%
2 in [1,2,3,4]
# Out:
# True

# %%
message.index('action',9+len('action'))
# Out:
# 51
