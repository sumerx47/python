# %% [markdown]
# # Strings Practise Exercise

# %%
name= 'sumer'
print(name)
# Out:
# sumer

# %%
s='python'
print(s[0],s[-1])
# Out:
# p n

# %%
s[2:]
# Out:
# 'thon'

# %%
s.upper()
# Out:
# 'PYTHON'

# %%
new='hello world'
print(s.upper())
# Out:
# PYTHON

# %%
new.replace('world','python')
# Out:
# 'hello python'

# %%
s='   Python is fun    '
s.strip()
# Out:
# 'Python is fun'

# %%
s='test'
'es' in s
# Out:
# True

# %%
s='learning'
s
# Out:
# 'learning'

# %%
s[::-1]
# Out:
# 'gninrael'

# %%
s='banana'
