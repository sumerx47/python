# %% [markdown]
# # Test

# %% [markdown]
# Write a Python program to:
# 1. Remove duplicate student records.
# 2. Find all unique course names.
# 3. Calculate the average marks for each course.
# 4. Find the student with the highest marks.
# 5. Print the names of students who have more than one record.
# 6. Create a dictionary where: Key = course name, Value = list of student names enrolled in that course (no duplicates).

# %%
students = [
    {"name": "Ali", "course": "Python", "marks": 85},
    {"name": "Sara", "course": "Java", "marks": 91},
    {"name": "Ali", "course": "Python", "marks": 85},
    {"name": "John", "course": "Python", "marks": 76},
    {"name": "Sara", "course": "Java", "marks": 91},
    {"name": "Fatima", "course": "C++", "marks": 88},
    {"name": "John", "course": "Python", "marks": 82},
    {"name": "Ahmed", "course": "Python", "marks": 92},
]

# %% [markdown]
# 1. Remove duplicate student records.

# %%
dup = []

# %%
import pprint
for student in students:
    if student["name"] in dup:
        students.remove(student)
    else:
        dup.append(student["name"])
pprint.pprint(students)
# Out:
# [{'course': 'C++', 'marks': 88, 'name': 'Fatima'}]

# %% [markdown]
# 2. Find all unique course names.

# %%
students = [
    {"name": "Ali", "course": "Python", "marks": 85},
    {"name": "Sara", "course": "Java", "marks": 91},
    {"name": "Ali", "course": "Python", "marks": 85},
    {"name": "John", "course": "Python", "marks": 76},
    {"name": "Sara", "course": "Java", "marks": 91},
    {"name": "Fatima", "course": "C++", "marks": 88},
    {"name": "John", "course": "Python", "marks": 82},
    {"name": "Ahmed", "course": "Python", "marks": 92},
]

# %%
course_name = []
#course = students[0]

# %%
for student in students:
        if student["course"] in course_name:
            continue
        else:
            course_name.append(student["course"])

print(course_name)

# Do THis using sets
# Out:
# ['Python', 'Java', 'C++']

# %%
s = set()

# %%
for student in students:
      s.add(student["course"])

print(s)
# Out:
# {'C++', 'Java', 'Python'}

# %%
students = [
    {"name": "Ali", "course": "Python", "marks": 85},
    {"name": "Sara", "course": "Java", "marks": 91},
    {"name": "Ali", "course": "Python", "marks": 85},
    {"name": "John", "course": "Python", "marks": 76},
    {"name": "Sara", "course": "Java", "marks": 91},
    {"name": "Fatima", "course": "C++", "marks": 88},
    {"name": "John", "course": "Python", "marks": 82},
    {"name": "Ahmed", "course": "Python", "marks": 92},
]

# %% [markdown]
# 3. Calculate the average marks for each course.

# %%
for student in students:
    totals = sum(student["marks"].values())
    Average = totals / len(student["marks"])
Average
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[119], line 2
#       1 for student in students:
# ----> 2     totals = sum(student["marks"].values())
#       3     Average = totals / len(student["marks"])
#       4 Average
#
# AttributeError: 'int' object has no attribute 'values'

# %% [markdown]
# 4. Find the student with the highest marks.

# %%
students = [
    {"name": "Ali", "course": "Python", "marks": 85},
    {"name": "Sara", "course": "Java", "marks": 91},
    {"name": "Ali", "course": "Python", "marks": 85},
    {"name": "John", "course": "Python", "marks": 76},
    {"name": "Sara", "course": "Java", "marks": 91},
    {"name": "Fatima", "course": "C++", "marks": 88},
    {"name": "John", "course": "Python", "marks": 82},
    {"name": "Ahmed", "course": "Python", "marks": 92},
]

# %%
unique = []
s = set()
total = 0

for student in students:
    if student["name"] not in s:
       unique.append(student)
       s.add(student["name"])
print(unique)
# Out:
# [{'name': 'Ali', 'course': 'Python', 'marks': 85}, {'name': 'Sara', 'course': 'Java', 'marks': 91}, {'name': 'John', 'course': 'Python', 'marks': 76}, {'name': 'Fatima', 'course': 'C++', 'marks': 88}, {'name': 'Ahmed', 'course': 'Python', 'marks': 92}]

# %%
for uniq in unique:
    avg = sum(uniq["marks"]) / len(uniq["marks"])
print(avg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 2
#       1 for uniq in unique:
# ----> 2     avg = sum(uniq["marks"]) / len(uniq["marks"])
#       3 print(avg)
#
# TypeError: 'int' object is not iterable

# %%
highest = max(students, key = lambda student :student ["marks"])
highest
# Out:
# {'name': 'Ahmed', 'course': 'Python', 'marks': 92}

# %%
count = []

# %%
sentense = "python is easy python is powerful"

# %%
words= sentense.lower().split()
words
# Out:
# ['python', 'is', 'easy', 'python', 'is', 'powerful']

# %%
for word in words:
    if word == :
        count = word + 1
print(count)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 2
#       1 for word in words:
# ----> 2     word = count+1
#       3
#       4 print(count)
#
# TypeError: can only concatenate list (not "int") to list
