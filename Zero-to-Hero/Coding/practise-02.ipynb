# %% [markdown]
# # practise coding from basic to advanced
# ## filtering ,    & manual coding
# ### Repeat: min , max, count & manual coding

# %% [markdown]
# 🟢 Level 1 (Intermediate)
#
# Question 1
#
# Tasks
#
# 1. Highest salary employee.
#
#
# 2. Lowest salary employee.
#
#
# 3. Count salaries.
#
#
# 4. Count departments.
#
#
# 5. Print employees earning above ₹50,000.
#
#
# 6. Print only IT employees.

# %%
employees = [
    {"name":"Ali","salary":45000,"dept":"IT"},
    {"name":"Sara","salary":65000,"dept":"HR"},
    {"name":"Ahmed","salary":55000,"dept":"IT"},
    {"name":"John","salary":70000,"dept":"Finance"},
    {"name":"Fatima","salary":45000,"dept":"HR"}
]

# %%
highest = employees[0]
lowest =employees[0]
salary_count={}
dept_count={}


for emp in employees:
    if emp["salary"] > highest["salary"]:
        highest = emp
    
    if emp['salary'] < lowest['salary']:
        lowest = emp
        
    salary = emp["salary"]
    if salary in salary_count:
        salary_count[salary] += 1
    else :
        salary_count[salary] =1

    dept =emp["dept"]
    if dept in dept_count:
        dept_count[dept] += 1
    else:
        dept_count[dept] = 1

print("Highest salary employee: ",highest["name"], highest["salary"])
print("Lowest salary employee: ",lowest["name"], lowest["salary"])
print("salaries Count: ",salary_count)
print("departments Count: ",dept_count)
print("*" * 15)

for emp in employees:
    if emp["salary"] > 50000:
        print("employees earning above ₹50,000: ",emp["name"])
print("*" * 15)
for emp in employees:
    if emp["dept"] =="IT":
        print("only IT employees: ",emp["name"])
# Out:
# Highest salary employee:  John 70000
# Lowest salary employee:  Ali 45000
# salaries Count:  {45000: 2, 65000: 1, 55000: 1, 70000: 1}
# departments Count:  {'IT': 2, 'HR': 2, 'Finance': 1}
# ***************
# employees earning above ₹50,000:  Sara
# employees earning above ₹50,000:  Ahmed
# employees earning above ₹50,000:  John
# ***************
# only IT employees:  Ali
# only IT employees:  Ahmed
