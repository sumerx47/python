# %% [markdown]
# # 4. create New List
# ## Basics to Advanced

# %% [markdown]
# 🟢 Homework (Level 1)
#
# Question 1
#
# Create a list of student names scoring above 80.

# %%
students = [
    {"name":"Ali","marks":90},
    {"name":"Sara","marks":75},
    {"name":"Ahmed","marks":88},
    {"name":"John","marks":60}
]
