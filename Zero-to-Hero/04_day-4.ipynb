# %% [markdown]
# # DAY-4

# %% [markdown]
# 1. REVERSE a string

# %%
text = "iam sumair"

# %%
text[::-1]
# Out:
# 'riamus mai'

# %%
reverse=""

# %%
for i in text:
    reverse = i + reverse
print(reverse)
# Out:
# riamus mai

# %% [markdown]
# 32. check palindrome string
