# %% [markdown]
# # Day 1

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print("my name is sumair.\niam learning python.\ni want to become a devops engineer.")
# Out:
# my name is sumair.
# iam learning python.
# i want to become a devops engineer.

# %%
name = "sumair"
age=26
city ="hyderabad"
profession="devops engineer"

# %%
print(f"Name:{name}\nAge:{age}\nCity:{city}\nprofession:{profession}")
# Out:
# Name:sumair
# Age:26
# City:hyderabad
# profession:devops engineer

# %%
a=10
b=5

# %%
print("sum=", a+b)
print("difference=", a-b)
print("product=",a*b) 
print("division=", a/b)
# Out:
# sum= 15
# difference= 5
# product= 50
# division= 2.0

# %% [markdown]
# ### Q5. swap numbers

# %%
a=10
b=20

# %%
a,b
# Out:
# (10, 20)

# %%
a,b=b,a

# %%
print(f"a={a}, b={b}")
# Out:
# a=20, b=10

# %% [markdown]
# ### Q6. area of rectangle

# %%
length =5
width =10

# %%
area=length*width

# %%
print(area)
# Out:
# 50

# %% [markdown]
# ### Q7. area of circle

# %%
pi=3.14
radius=4

# %%
area_circle = pi * radius **2

# %%
print(area_circle)
# Out:
# 50.24

# %% [markdown]
# ### Q8.celsius to farenheit

# %%
celsius=25

# %%
farenheit = (celsius*9/5)+32

# %%
print(farenheit)
# Out:
# 77.0

# %% [markdown]
# ### Q9. avg of 5 numbers

# %%
a=10
b=20
c=30
d=40
e=50

# %%
avg = (a+b+c+d+e)/5
print(avg)
# Out:
# 30.0

# %% [markdown]
# ### q10. simple calculator

# %%
choice = 1

# %%
print(f"enter your choice: {choice}")
# Out:
# enter your choice: 4

# %%
a=10
b=20

# %%
if choice == 1:
    print("sum=", a+b)
elif choice == 2:
    print("sub=", a-b)
elif choice == 3:
    print("mul=", a*b)
elif choice == 4:
    print("div=", a/b)
else :
    print("enter correct number")
# Out:
# sum= 30
